# %%
from pymongo import MongoClient
client = MongoClient()
db = client.vpexp1
solutions = db.solutions
solutions.count()
# Out:
# 232320

# %%
results = solutions.group(["pack", "select"], {}, { 'problems_solved' : 0, 'items_unmapped' : 0 }, 
    'function(curr, result) { if (curr.failcount == 0) { result.problems_solved++; }; result.items_unmapped += curr.failcount; }')

# %%
print solutions.count() / (2 * 15)
print
print "solved\tpack\tselect"
for result in sorted(results, key=lambda x: x['problems_solved'], reverse=True):
    print "%(problems_solved)d\t%(pack)s\t%(select)s" % result
print
print "unmapped\tpack\tselect"
for result in sorted(results, key=lambda x: x['items_unmapped']):
    print "%(items_unmapped)d\t%(pack)s\t%(select)s" % result
# Out:
# 7744
#
# solved	pack	select
# 7045	pack_by_bins	a:maxdiff
# 6992	pack_by_bins	a:lnorm
# 6963	pack_by_bins	a:maxratio
# 6915	pack_by_bins	a:max
# 6807	pack_by_bins	pp
# 6805	pack_by_items	pp
# 6786	pack_by_bins	pp:w=2
# 6773	pack_by_items	pp:w=2
# 6709	pack_by_bins	cp:w=2
# 6693	pack_by_items	cp:w=2
# 6643	pack_by_items	a:maxratio
# 6426	pack_by_items	a:maxdiff
# 6405	pack_by_bins	cp:w=1
# 6394	pack_by_items	cp:w=1
# 6274	pack_by_bins	a:sum
# 6242	pack_by_items	a:max
# 6237	pack_by_items	a:lnorm
# 6197	pack_by_items	a:sum
# 6182	pack_by_items	none
# 6182	pack_by_bins	none
# 6165	pack_by_bins	d:sum
# 6040	pack_by_items	d:maxratio
# 5981	pack_by_items	d:sum
# 5709	pack_by_items	d:maxdiff
# 5292	pack_by_items	d:max
# 5276	pack_by_bins	d:max
# 5079	pack_by_items	d:lnorm
# 4996	pack_by_bins	d:maxratio
# 4950	pack_by_bins	d:lnorm
# 4942	pack_by_bins	d:maxdiff
#
# unmapped	pack	select
# 248062	pack_by_bins	a:maxratio
# 257372	pack_by_bins	a:maxdiff
# 423379	pack_by_bins	pp
# 466645	pack_by_bins	a:lnorm
# 508250	pack_by_bins	pp:w=2
# 583625	pack_by_items	pp
# 586906	pack_by_bins	a:max
# 614026	pack_by_bins	cp:w=2
# 648680	pack_by_items	pp:w=2
# 695168	pack_by_items	a:maxratio
# 739980	pack_by_items	cp:w=2
# 741928	pack_by_bins	cp:w=1
# 871610	pack_by_items	cp:w=1
# 885223	pack_by_items	a:maxdiff
# 890035	pack_by_bins	d:sum
# 1127249	pack_by_items	a:lnorm
# 1138480	pack_by_items	a:max
# 1185383	pack_by_bins	none
# 1210903	pack_by_items	a:sum
# 1265537	pack_by_items	none
# 1347628	pack_by_items	d:sum
# 1475939	pack_by_bins	a:sum
# 1513881	pack_by_items	d:maxratio
# 1808212	pack_by_items	d:maxdiff
# 1977725	pack_by_bins	d:max
# 2152700	pack_by_items	d:max
# 2506577	pack_by_items	d:lnorm
# 2552520	pack_by_bins	d:lnorm
# 3590374	pack_by_bins	d:maxdiff
# 3837172	pack_by_bins	d:maxratio

# %%
results = solutions.group(["pack", "select", "num_dimensions"], {}, { 'problems_solved' : 0, 'items_unmapped' : 0 }, 
    'function(curr, result) { if (curr.failcount == 0) { result.problems_solved++; }; result.items_unmapped += curr.failcount; }')

# %%
print "dims\tsolved\tpack\tselect"
for result in sorted(results, key=lambda x: (x['num_dimensions'], x['problems_solved']), reverse=True):
    print "%(num_dimensions)d\t%(problems_solved)d\t%(pack)s\t%(select)s" % result
print
print "dims\tunmapped\tpack\tselect"
for result in sorted(results, key=lambda x: (x['num_dimensions'], x['items_unmapped'])):
    print "%(num_dimensions)d\t%(items_unmapped)d\t%(pack)s\t%(select)s" % result
# Out:
# dims	solved	pack	select
# 4	1577	pack_by_bins	a:maxdiff
# 4	1573	pack_by_bins	a:max
# 4	1573	pack_by_bins	a:lnorm
# 4	1554	pack_by_bins	pp
# 4	1553	pack_by_bins	a:maxratio
# 4	1546	pack_by_items	pp
# 4	1533	pack_by_bins	pp:w=2
# 4	1516	pack_by_bins	cp:w=2
# 4	1514	pack_by_items	pp:w=2
# 4	1502	pack_by_items	cp:w=2
# 4	1418	pack_by_items	a:maxratio
# 4	1363	pack_by_items	a:maxdiff
# 4	1304	pack_by_bins	cp:w=1
# 4	1294	pack_by_items	cp:w=1
# 4	1289	pack_by_bins	a:sum
# 4	1276	pack_by_items	a:lnorm
# 4	1274	pack_by_items	a:max
# 4	1237	pack_by_items	a:sum
# 4	1230	pack_by_bins	none
# 4	1230	pack_by_items	none
# 4	1210	pack_by_bins	d:sum
# 4	1210	pack_by_items	d:sum
# 4	1210	pack_by_items	d:maxratio
# 4	1082	pack_by_items	d:maxdiff
# 4	968	pack_by_items	d:max
# 4	968	pack_by_bins	d:max
# 4	847	pack_by_items	d:lnorm
# 4	847	pack_by_bins	d:lnorm
# 4	845	pack_by_bins	d:maxratio
# 4	841	pack_by_bins	d:maxdiff
# 3	1736	pack_by_bins	a:maxdiff
# 3	1712	pack_by_bins	a:lnorm
# 3	1703	pack_by_bins	a:maxratio
# 3	1616	pack_by_items	pp
# 3	1616	pack_by_items	pp:w=2
# 3	1613	pack_by_bins	a:max
# 3	1609	pack_by_bins	pp
# 3	1609	pack_by_bins	pp:w=2
# 3	1563	pack_by_bins	cp:w=2
# 3	1562	pack_by_items	a:maxratio
# 3	1561	pack_by_items	cp:w=2
# 3	1457	pack_by_bins	cp:w=1
# 3	1457	pack_by_items	cp:w=1
# 3	1412	pack_by_items	a:maxdiff
# 3	1355	pack_by_bins	a:sum
# 3	1338	pack_by_items	a:max
# 3	1331	pack_by_items	a:lnorm
# 3	1330	pack_by_items	a:sum
# 3	1325	pack_by_bins	d:sum
# 3	1322	pack_by_items	none
# 3	1322	pack_by_bins	none
# 3	1241	pack_by_items	d:sum
# 3	1210	pack_by_items	d:maxdiff
# 3	1210	pack_by_items	d:maxratio
# 3	1122	pack_by_items	d:max
# 3	1089	pack_by_bins	d:max
# 3	994	pack_by_items	d:lnorm
# 3	884	pack_by_bins	d:maxratio
# 3	851	pack_by_bins	d:maxdiff
# 3	847	pack_by_bins	d:lnorm
# 2	1796	pack_by_bins	a:maxdiff
# 2	1793	pack_by_bins	a:max
# 2	1771	pack_by_bins	a:maxratio
# 2	1771	pack_by_bins	a:lnorm
# 2	1727	pack_by_items	a:maxratio
# 2	1715	pack_by_items	a:maxdiff
# 2	1708	pack_by_bins	pp
# 2	1708	pack_by_bins	pp:w=2
# 2	1708	pack_by_bins	cp:w=1
# 2	1707	pack_by_items	pp
# 2	1707	pack_by_items	pp:w=2
# 2	1707	pack_by_items	cp:w=1
# 2	1694	pack_by_items	a:lnorm
# 2	1694	pack_by_items	none
# 2	1694	pack_by_items	cp:w=2
# 2	1694	pack_by_items	a:sum
# 2	1694	pack_by_items	a:max
# 2	1694	pack_by_bins	cp:w=2
# 2	1694	pack_by_bins	none
# 2	1694	pack_by_bins	a:sum
# 2	1694	pack_by_bins	d:sum
# 2	1684	pack_by_items	d:maxratio
# 2	1649	pack_by_items	d:sum
# 2	1481	pack_by_items	d:maxdiff
# 2	1357	pack_by_items	d:lnorm
# 2	1331	pack_by_bins	d:maxratio
# 2	1321	pack_by_items	d:max
# 2	1320	pack_by_bins	d:lnorm
# 2	1314	pack_by_bins	d:maxdiff
# 2	1283	pack_by_bins	d:max
# 1	1936	pack_by_items	none
# 1	1936	pack_by_items	cp:w=2
# 1	1936	pack_by_items	a:sum
# 1	1936	pack_by_items	a:max
# 1	1936	pack_by_items	a:maxdiff
# 1	1936	pack_by_items	d:maxdiff
# 1	1936	pack_by_items	a:maxratio
# 1	1936	pack_by_items	d:maxratio
# 1	1936	pack_by_items	a:lnorm
# 1	1936	pack_by_items	pp
# 1	1936	pack_by_items	pp:w=2
# 1	1936	pack_by_items	cp:w=1
# 1	1936	pack_by_bins	none
# 1	1936	pack_by_bins	a:sum
# 1	1936	pack_by_bins	d:sum
# 1	1936	pack_by_bins	a:max
# 1	1936	pack_by_bins	d:max
# 1	1936	pack_by_bins	a:maxdiff
# 1	1936	pack_by_bins	d:maxdiff
# 1	1936	pack_by_bins	a:maxratio
# 1	1936	pack_by_bins	d:maxratio
# 1	1936	pack_by_bins	a:lnorm
# 1	1936	pack_by_bins	d:lnorm
# 1	1936	pack_by_bins	pp
# 1	1936	pack_by_bins	pp:w=2
# 1	1936	pack_by_bins	cp:w=1
# 1	1936	pack_by_bins	cp:w=2
# 1	1881	pack_by_items	d:sum
# 1	1881	pack_by_items	d:max
# 1	1881	pack_by_items	d:lnorm
#
# dims	unmapped	pack	select
# 1	0	pack_by_items	none
# 1	0	pack_by_items	cp:w=2
# 1	0	pack_by_items	a:sum
# 1	0	pack_by_items	a:max
# 1	0	pack_by_items	a:maxdiff
# 1	0	pack_by_items	d:maxdiff
# 1	0	pack_by_items	a:maxratio
# 1	0	pack_by_items	d:maxratio
# 1	0	pack_by_items	a:lnorm
# 1	0	pack_by_items	pp
# 1	0	pack_by_items	pp:w=2
# 1	0	pack_by_items	cp:w=1
# 1	0	pack_by_bins	none
# 1	0	pack_by_bins	a:sum
# 1	0	pack_by_bins	d:sum
# 1	0	pack_by_bins	a:max
# 1	0	pack_by_bins	d:max
# 1	0	pack_by_bins	a:maxdiff
# 1	0	pack_by_bins	d:maxdiff
# 1	0	pack_by_bins	a:maxratio
# 1	0	pack_by_bins	d:maxratio
# 1	0	pack_by_bins	a:lnorm
# 1	0	pack_by_bins	d:lnorm
# 1	0	pack_by_bins	pp
# 1	0	pack_by_bins	pp:w=2
# 1	0	pack_by_bins	cp:w=1
# 1	0	pack_by_bins	cp:w=2
# 1	2640	pack_by_items	d:sum
# 1	2640	pack_by_items	d:max
# 1	2640	pack_by_items	d:lnorm
# 2	3849	pack_by_bins	a:maxdiff
# 2	7056	pack_by_bins	a:maxratio
# 2	9106	pack_by_bins	a:max
# 2	19280	pack_by_bins	a:lnorm
# 2	34442	pack_by_bins	pp
# 2	34442	pack_by_bins	pp:w=2
# 2	34442	pack_by_bins	cp:w=1
# 2	50086	pack_by_items	pp
# 2	50086	pack_by_items	pp:w=2
# 2	50086	pack_by_items	cp:w=1
# 2	62268	pack_by_items	a:maxdiff
# 2	68971	pack_by_items	a:maxratio
# 2	73272	pack_by_bins	d:sum
# 2	96395	pack_by_items	a:max
# 2	98734	pack_by_items	a:lnorm
# 2	105097	pack_by_bins	cp:w=2
# 2	105097	pack_by_bins	none
# 2	111038	pack_by_items	a:sum
# 2	118504	pack_by_items	none
# 2	118504	pack_by_items	cp:w=2
# 2	143916	pack_by_items	d:sum
# 2	146791	pack_by_items	d:maxratio
# 2	152689	pack_by_bins	a:sum
# 2	206087	pack_by_items	d:maxdiff
# 2	321818	pack_by_bins	d:lnorm
# 2	374116	pack_by_items	d:lnorm
# 2	384063	pack_by_bins	d:max
# 2	405023	pack_by_items	d:max
# 2	536186	pack_by_bins	d:maxdiff
# 2	627775	pack_by_bins	d:maxratio
# 3	39394	pack_by_bins	a:maxdiff
# 3	43489	pack_by_bins	a:maxratio
# 3	70526	pack_by_bins	a:lnorm
# 3	83513	pack_by_bins	pp
# 3	83513	pack_by_bins	pp:w=2
# 3	97101	pack_by_bins	a:max
# 3	107032	pack_by_bins	cp:w=2
# 3	123620	pack_by_items	pp
# 3	123620	pack_by_items	pp:w=2
# 3	144898	pack_by_items	cp:w=2
# 3	158723	pack_by_items	a:maxratio
# 3	165577	pack_by_bins	cp:w=1
# 3	216816	pack_by_items	cp:w=1
# 3	223569	pack_by_items	a:maxdiff
# 3	231285	pack_by_bins	d:sum
# 3	322493	pack_by_items	a:lnorm
# 3	324295	pack_by_items	a:max
# 3	339968	pack_by_bins	none
# 3	350449	pack_by_items	a:sum
# 3	371329	pack_by_items	none
# 3	394014	pack_by_items	d:sum
# 3	445903	pack_by_bins	a:sum
# 3	474431	pack_by_items	d:maxratio
# 3	615255	pack_by_items	d:maxdiff
# 3	659824	pack_by_bins	d:max
# 3	739351	pack_by_items	d:max
# 3	900051	pack_by_items	d:lnorm
# 3	915699	pack_by_bins	d:lnorm
# 3	1347024	pack_by_bins	d:maxdiff
# 3	1438188	pack_by_bins	d:maxratio
# 4	197517	pack_by_bins	a:maxratio
# 4	214129	pack_by_bins	a:maxdiff
# 4	305424	pack_by_bins	pp
# 4	376839	pack_by_bins	a:lnorm
# 4	390295	pack_by_bins	pp:w=2
# 4	401897	pack_by_bins	cp:w=2
# 4	409919	pack_by_items	pp
# 4	467474	pack_by_items	a:maxratio
# 4	474974	pack_by_items	pp:w=2
# 4	476578	pack_by_items	cp:w=2
# 4	480699	pack_by_bins	a:max
# 4	541909	pack_by_bins	cp:w=1
# 4	585478	pack_by_bins	d:sum
# 4	599386	pack_by_items	a:maxdiff
# 4	604708	pack_by_items	cp:w=1
# 4	706022	pack_by_items	a:lnorm
# 4	717790	pack_by_items	a:max
# 4	740318	pack_by_bins	none
# 4	749416	pack_by_items	a:sum
# 4	775704	pack_by_items	none
# 4	807058	pack_by_items	d:sum
# 4	877347	pack_by_bins	a:sum
# 4	892659	pack_by_items	d:maxratio
# 4	933838	pack_by_bins	d:max
# 4	986870	pack_by_items	d:maxdiff
# 4	1005686	pack_by_items	d:max
# 4	1229770	pack_by_items	d:lnorm
# 4	1315003	pack_by_bins	d:lnorm
# 4	1707164	pack_by_bins	d:maxdiff
# 4	1771209	pack_by_bins	d:maxratio

# %%
results = solutions.group(["pack", "select", "itemsort", "binsort"], {}, { 'problems_solved' : 0, 'items_unmapped' : 0 }, 
    'function(curr, result) { if (curr.failcount == 0) { result.problems_solved++; }; result.items_unmapped += curr.failcount; }')

# %%
print solutions.count() / (2 * 15 * 11 * 11)
print
print "solved\tpack\tselect\titemsort\tbinsort"
for result in sorted(results, key=lambda x: x['problems_solved'], reverse=True)[:20]:
    print "%(problems_solved)d\t%(pack)s\t%(select)s\t%(itemsort)s\t%(binsort)s" % result
print
print "unmapped\tpack\tselect\titemsort\tbinsort"
for result in sorted(results, key=lambda x: x['items_unmapped'])[:20]:
    print "%(items_unmapped)d\t%(pack)s\t%(select)s\t%(itemsort)s\t%(binsort)s" % result
# Out:
# 64
#
# solved	pack	select	itemsort	binsort
# 60	pack_by_bins	a:maxdiff	d:lnorm	d:maxratio
# 60	pack_by_bins	a:maxratio	d:lnorm	d:maxratio
# 60	pack_by_bins	a:maxdiff	d:maxratio	d:maxratio
# 60	pack_by_bins	a:maxdiff	d:maxdiff	d:maxratio
# 60	pack_by_bins	a:maxdiff	d:sum	d:maxratio
# 60	pack_by_bins	a:maxratio	d:sum	d:maxratio
# 60	pack_by_bins	a:maxdiff	a:max	d:maxratio
# 60	pack_by_bins	a:maxdiff	none	d:maxratio
# 59	pack_by_bins	a:lnorm	d:lnorm	d:sum
# 59	pack_by_bins	a:lnorm	d:lnorm	d:lnorm
# 59	pack_by_bins	a:maxdiff	a:lnorm	a:sum
# 59	pack_by_bins	a:maxdiff	a:lnorm	d:maxdiff
# 59	pack_by_bins	a:maxdiff	a:lnorm	d:maxratio
# 59	pack_by_bins	a:maxdiff	a:lnorm	a:lnorm
# 59	pack_by_bins	a:lnorm	a:lnorm	none
# 59	pack_by_bins	a:lnorm	a:lnorm	d:sum
# 59	pack_by_bins	a:lnorm	a:lnorm	d:lnorm
# 59	pack_by_bins	a:maxdiff	d:lnorm	none
# 59	pack_by_bins	a:maxdiff	d:lnorm	a:sum
# 59	pack_by_bins	a:maxdiff	d:lnorm	d:maxdiff
#
# unmapped	pack	select	itemsort	binsort
# 1395	pack_by_bins	a:maxratio	d:sum	d:maxratio
# 1405	pack_by_bins	a:maxratio	d:lnorm	d:maxratio
# 1459	pack_by_bins	a:maxratio	d:maxratio	d:maxratio
# 1467	pack_by_bins	a:maxratio	d:max	d:maxratio
# 1470	pack_by_bins	a:maxratio	d:maxdiff	d:maxratio
# 1520	pack_by_bins	a:maxratio	d:lnorm	d:maxdiff
# 1520	pack_by_bins	a:maxratio	d:sum	d:maxdiff
# 1541	pack_by_bins	a:maxratio	d:sum	a:sum
# 1548	pack_by_bins	a:maxratio	d:lnorm	a:sum
# 1591	pack_by_bins	a:maxratio	d:max	d:maxdiff
# 1592	pack_by_bins	a:maxratio	d:max	a:sum
# 1596	pack_by_bins	a:maxdiff	a:max	d:maxratio
# 1604	pack_by_bins	a:maxratio	d:lnorm	a:lnorm
# 1607	pack_by_bins	a:maxratio	d:maxdiff	d:maxdiff
# 1608	pack_by_bins	a:maxratio	d:maxdiff	a:sum
# 1609	pack_by_bins	a:maxratio	none	d:maxratio
# 1611	pack_by_bins	a:maxratio	d:maxratio	a:sum
# 1611	pack_by_bins	a:maxratio	d:maxratio	d:maxdiff
# 1612	pack_by_bins	a:maxdiff	d:maxratio	d:maxratio
# 1614	pack_by_bins	a:maxdiff	a:lnorm	d:maxratio

# %%
for num_dimensions in [1, 2, 3, 4]:
    print "num_dimensions: %d\n" % (num_dimensions)
    results = solutions.group(['pack', 'select', 'itemsort', 'binsort'], { 'num_dimensions' : num_dimensions }, 
                              { 'problems_solved' : 0, 'items_unmapped' : 0 }, 
        'function(curr, result) { if (curr.failcount == 0) { result.problems_solved++; }; result.items_unmapped += curr.failcount; }')
    
    print "solved\tpack\tselect\titemsort\tbinsort"
    for result in sorted(results, key=lambda x: x['problems_solved'], reverse=True)[:40]:
        print "%(problems_solved)d\t%(pack)s\t%(select)s\t%(itemsort)s\t%(binsort)s" % result
    print
    print "unmapped\tpack\tselect\titemsort\tbinsort"
    for result in sorted(results, key=lambda x: x['items_unmapped'])[:40]:
        print "%(items_unmapped)d\t%(pack)s\t%(select)s\t%(itemsort)s\t%(binsort)s" % result
    print
# Out:
# num_dimensions: 1
#
# solved	pack	select	itemsort	binsort
# 16	pack_by_items	none	d:maxratio	d:lnorm
# 16	pack_by_items	cp:w=2	a:maxratio	d:maxdiff
# 16	pack_by_items	cp:w=2	a:maxratio	d:maxratio
# 16	pack_by_items	cp:w=2	a:maxratio	a:maxratio
# 16	pack_by_items	cp:w=2	a:maxratio	a:maxdiff
# 16	pack_by_items	cp:w=2	a:maxratio	d:lnorm
# 16	pack_by_items	a:sum	d:maxratio	none
# 16	pack_by_items	a:sum	d:maxratio	a:sum
# 16	pack_by_items	a:sum	d:maxratio	a:max
# 16	pack_by_items	a:sum	d:maxratio	d:sum
# 16	pack_by_items	a:sum	d:maxratio	d:max
# 16	pack_by_items	a:sum	d:maxratio	a:maxdiff
# 16	pack_by_items	a:sum	d:maxratio	d:maxdiff
# 16	pack_by_items	a:sum	d:maxratio	a:maxratio
# 16	pack_by_items	a:sum	d:maxratio	d:lnorm
# 16	pack_by_items	a:sum	d:maxratio	a:lnorm
# 16	pack_by_items	a:sum	d:maxratio	d:maxratio
# 16	pack_by_items	a:max	d:maxratio	none
# 16	pack_by_items	a:max	d:maxratio	d:sum
# 16	pack_by_items	a:max	d:maxratio	a:sum
# 16	pack_by_items	a:max	d:maxratio	a:max
# 16	pack_by_items	a:max	d:maxratio	a:maxdiff
# 16	pack_by_items	a:max	d:maxratio	d:max
# 16	pack_by_items	a:max	d:maxratio	d:maxdiff
# 16	pack_by_items	a:max	d:maxratio	d:maxratio
# 16	pack_by_items	a:max	d:maxratio	a:maxratio
# 16	pack_by_items	a:max	d:maxratio	a:lnorm
# 16	pack_by_items	a:max	d:maxratio	d:lnorm
# 16	pack_by_items	a:maxdiff	d:maxratio	a:sum
# 16	pack_by_items	a:maxdiff	d:maxratio	a:max
# 16	pack_by_items	a:maxdiff	d:maxratio	d:sum
# 16	pack_by_items	a:maxdiff	d:maxratio	none
# 16	pack_by_items	a:maxdiff	d:maxratio	a:lnorm
# 16	pack_by_items	a:maxdiff	d:maxratio	d:max
# 16	pack_by_items	a:maxdiff	d:maxratio	a:maxdiff
# 16	pack_by_items	a:maxdiff	d:maxratio	a:maxratio
# 16	pack_by_items	a:maxdiff	d:maxratio	d:maxdiff
# 16	pack_by_items	a:maxdiff	d:maxratio	d:maxratio
# 16	pack_by_items	a:maxdiff	d:maxratio	d:lnorm
# 16	pack_by_items	d:maxdiff	d:maxratio	a:sum
#
# unmapped	pack	select	itemsort	binsort
# 0	pack_by_items	none	d:maxratio	d:lnorm
# 0	pack_by_items	cp:w=2	a:maxratio	d:maxdiff
# 0	pack_by_items	cp:w=2	a:maxratio	d:maxratio
# 0	pack_by_items	cp:w=2	a:maxratio	a:maxratio
# 0	pack_by_items	cp:w=2	a:maxratio	a:maxdiff
# 0	pack_by_items	cp:w=2	a:maxratio	d:lnorm
# 0	pack_by_items	a:sum	d:maxratio	none
# 0	pack_by_items	a:sum	d:maxratio	a:sum
# 0	pack_by_items	a:sum	d:maxratio	a:max
# 0	pack_by_items	a:sum	d:maxratio	d:sum
# 0	pack_by_items	a:sum	d:maxratio	d:max
# 0	pack_by_items	a:sum	d:maxratio	a:maxdiff
# 0	pack_by_items	a:sum	d:maxratio	d:maxdiff
# 0	pack_by_items	a:sum	d:maxratio	a:maxratio
# 0	pack_by_items	a:sum	d:maxratio	d:lnorm
# 0	pack_by_items	a:sum	d:maxratio	a:lnorm
# 0	pack_by_items	a:sum	d:maxratio	d:maxratio
# 0	pack_by_items	a:max	d:maxratio	none
# 0	pack_by_items	a:max	d:maxratio	d:sum
# 0	pack_by_items	a:max	d:maxratio	a:sum
# 0	pack_by_items	a:max	d:maxratio	a:max
# 0	pack_by_items	a:max	d:maxratio	a:maxdiff
# 0	pack_by_items	a:max	d:maxratio	d:max
# 0	pack_by_items	a:max	d:maxratio	d:maxdiff
# 0	pack_by_items	a:max	d:maxratio	d:maxratio
# 0	pack_by_items	a:max	d:maxratio	a:maxratio
# 0	pack_by_items	a:max	d:maxratio	a:lnorm
# 0	pack_by_items	a:max	d:maxratio	d:lnorm
# 0	pack_by_items	a:maxdiff	d:maxratio	a:sum
# 0	pack_by_items	a:maxdiff	d:maxratio	a:max
# 0	pack_by_items	a:maxdiff	d:maxratio	d:sum
# 0	pack_by_items	a:maxdiff	d:maxratio	none
# 0	pack_by_items	a:maxdiff	d:maxratio	a:lnorm
# 0	pack_by_items	a:maxdiff	d:maxratio	d:max
# 0	pack_by_items	a:maxdiff	d:maxratio	a:maxdiff
# 0	pack_by_items	a:maxdiff	d:maxratio	a:maxratio
# 0	pack_by_items	a:maxdiff	d:maxratio	d:maxdiff
# 0	pack_by_items	a:maxdiff	d:maxratio	d:maxratio
# 0	pack_by_items	a:maxdiff	d:maxratio	d:lnorm
# 0	pack_by_items	d:maxdiff	d:maxratio	a:sum
#
# num_dimensions: 2
#
# solved	pack	select	itemsort	binsort
# 15	pack_by_items	a:maxdiff	a:maxdiff	none
# 15	pack_by_items	a:maxdiff	a:maxdiff	d:sum
# 15	pack_by_items	a:maxdiff	a:maxdiff	a:max
# 15	pack_by_items	a:maxdiff	a:maxdiff	d:maxdiff
# 15	pack_by_items	a:maxdiff	a:maxdiff	a:maxdiff
# 15	pack_by_items	a:maxdiff	a:maxdiff	d:max
# 15	pack_by_items	a:maxdiff	a:maxdiff	d:maxratio
# 15	pack_by_items	a:maxdiff	a:maxdiff	d:lnorm
# 15	pack_by_items	a:maxdiff	a:maxdiff	a:maxratio
# 15	pack_by_items	a:maxdiff	a:maxdiff	a:lnorm
# 15	pack_by_items	a:maxratio	a:maxdiff	none
# 15	pack_by_items	a:maxratio	a:maxdiff	d:sum
# 15	pack_by_items	a:maxratio	a:maxdiff	a:sum
# 15	pack_by_items	a:maxratio	a:maxdiff	a:maxdiff
# 15	pack_by_items	a:maxratio	a:maxdiff	d:max
# 15	pack_by_items	a:maxratio	a:maxdiff	a:max
# 15	pack_by_items	a:maxratio	a:maxdiff	a:maxratio
# 15	pack_by_items	a:maxratio	a:maxdiff	a:lnorm
# 15	pack_by_items	a:maxratio	a:maxdiff	d:maxratio
# 15	pack_by_items	a:maxratio	a:maxdiff	d:maxdiff
# 15	pack_by_items	a:maxratio	a:maxdiff	d:lnorm
# 15	pack_by_items	pp	a:maxdiff	a:maxdiff
# 15	pack_by_items	pp	a:maxdiff	a:maxratio
# 15	pack_by_items	pp:w=2	a:maxdiff	a:maxratio
# 15	pack_by_items	pp:w=2	a:maxdiff	a:maxdiff
# 15	pack_by_items	cp:w=1	a:maxdiff	a:maxdiff
# 15	pack_by_items	cp:w=1	a:maxdiff	a:maxratio
# 15	pack_by_bins	a:max	a:maxdiff	none
# 15	pack_by_bins	a:max	a:maxdiff	d:sum
# 15	pack_by_bins	a:max	a:maxdiff	a:max
# 15	pack_by_bins	a:max	a:maxdiff	d:max
# 15	pack_by_bins	a:max	a:maxdiff	a:maxdiff
# 15	pack_by_bins	a:max	a:maxdiff	a:maxratio
# 15	pack_by_bins	a:max	a:maxdiff	d:lnorm
# 15	pack_by_bins	a:maxdiff	a:maxdiff	a:sum
# 15	pack_by_bins	a:maxdiff	a:maxdiff	none
# 15	pack_by_bins	a:maxdiff	a:maxdiff	d:sum
# 15	pack_by_bins	a:maxdiff	a:maxdiff	a:max
# 15	pack_by_bins	a:maxdiff	a:maxdiff	d:max
# 15	pack_by_bins	a:maxdiff	a:maxdiff	d:maxdiff
#
# unmapped	pack	select	itemsort	binsort
# 7	pack_by_bins	a:maxdiff	a:maxdiff	d:maxratio
# 7	pack_by_bins	a:maxdiff	d:maxdiff	d:maxratio
# 7	pack_by_bins	a:maxdiff	none	d:maxratio
# 9	pack_by_bins	a:maxdiff	a:maxratio	d:maxdiff
# 9	pack_by_bins	a:maxdiff	a:maxratio	d:maxratio
# 9	pack_by_bins	a:maxdiff	d:maxratio	d:maxratio
# 9	pack_by_bins	a:maxdiff	a:lnorm	d:maxratio
# 9	pack_by_bins	a:maxdiff	d:lnorm	d:maxdiff
# 9	pack_by_bins	a:maxdiff	d:lnorm	d:maxratio
# 9	pack_by_bins	a:maxdiff	a:sum	d:maxratio
# 9	pack_by_bins	a:maxdiff	d:sum	d:maxdiff
# 9	pack_by_bins	a:maxdiff	d:sum	d:maxratio
# 9	pack_by_bins	a:maxdiff	a:max	d:maxratio
# 9	pack_by_bins	a:maxdiff	d:max	d:maxratio
# 9	pack_by_bins	a:maxdiff	d:max	d:maxdiff
# 10	pack_by_bins	a:maxdiff	a:maxdiff	d:maxdiff
# 10	pack_by_bins	a:maxdiff	d:maxdiff	d:maxdiff
# 10	pack_by_bins	pp	d:maxratio	d:maxratio
# 10	pack_by_bins	pp:w=2	d:maxratio	d:maxratio
# 10	pack_by_bins	cp:w=1	d:maxratio	d:maxratio
# 10	pack_by_bins	a:maxdiff	none	d:maxdiff
# 11	pack_by_bins	pp	d:maxdiff	d:maxratio
# 11	pack_by_bins	pp:w=2	d:maxdiff	d:maxratio
# 11	pack_by_bins	cp:w=1	d:maxdiff	d:maxratio
# 11	pack_by_items	pp	d:maxdiff	d:maxratio
# 11	pack_by_items	pp:w=2	d:maxdiff	d:maxratio
# 11	pack_by_items	cp:w=1	d:maxdiff	d:maxratio
# 14	pack_by_bins	a:maxdiff	d:maxratio	d:maxdiff
# 14	pack_by_bins	a:maxratio	d:lnorm	d:maxratio
# 14	pack_by_bins	a:maxratio	d:sum	d:maxratio
# 15	pack_by_bins	a:maxdiff	d:maxratio	a:sum
# 15	pack_by_bins	a:maxdiff	a:lnorm	d:maxdiff
# 15	pack_by_bins	a:maxdiff	d:lnorm	a:sum
# 15	pack_by_bins	a:maxdiff	d:lnorm	a:lnorm
# 15	pack_by_bins	a:maxdiff	a:sum	d:maxdiff
# 15	pack_by_bins	a:maxdiff	d:sum	a:sum
# 15	pack_by_bins	a:maxdiff	d:sum	a:lnorm
# 15	pack_by_bins	a:maxdiff	a:max	d:maxdiff
# 15	pack_by_bins	a:maxdiff	d:max	a:sum
# 16	pack_by_bins	a:maxdiff	a:maxdiff	a:sum
#
# num_dimensions: 3
#
# solved	pack	select	itemsort	binsort
# 15	pack_by_bins	a:lnorm	d:lnorm	d:sum
# 15	pack_by_bins	a:lnorm	d:lnorm	d:lnorm
# 15	pack_by_bins	a:maxdiff	a:lnorm	a:sum
# 15	pack_by_bins	a:maxdiff	a:lnorm	d:maxdiff
# 15	pack_by_bins	a:maxdiff	a:lnorm	d:maxratio
# 15	pack_by_bins	a:maxdiff	a:lnorm	a:lnorm
# 15	pack_by_bins	a:lnorm	a:lnorm	none
# 15	pack_by_bins	a:lnorm	a:lnorm	d:sum
# 15	pack_by_bins	a:lnorm	a:lnorm	d:lnorm
# 15	pack_by_bins	a:maxdiff	d:lnorm	none
# 15	pack_by_bins	a:maxdiff	d:lnorm	a:sum
# 15	pack_by_bins	a:maxdiff	d:lnorm	d:maxdiff
# 15	pack_by_bins	a:maxdiff	d:lnorm	d:maxratio
# 15	pack_by_bins	a:maxdiff	d:lnorm	a:lnorm
# 15	pack_by_bins	a:maxratio	d:lnorm	a:sum
# 15	pack_by_bins	a:maxratio	d:lnorm	d:maxdiff
# 15	pack_by_bins	a:maxratio	d:lnorm	d:maxratio
# 15	pack_by_bins	a:maxratio	d:lnorm	a:lnorm
# 15	pack_by_bins	a:lnorm	d:lnorm	none
# 15	pack_by_bins	a:maxdiff	a:maxratio	a:sum
# 15	pack_by_bins	a:maxdiff	a:maxratio	d:maxdiff
# 15	pack_by_bins	a:maxdiff	a:maxratio	d:maxratio
# 15	pack_by_bins	a:lnorm	a:maxratio	none
# 15	pack_by_bins	a:lnorm	a:maxratio	d:sum
# 15	pack_by_bins	a:lnorm	a:maxratio	d:lnorm
# 15	pack_by_bins	a:maxdiff	d:maxratio	a:sum
# 15	pack_by_bins	a:maxdiff	d:maxratio	d:maxdiff
# 15	pack_by_bins	a:maxdiff	d:maxratio	d:maxratio
# 15	pack_by_bins	a:maxratio	d:maxratio	a:sum
# 15	pack_by_bins	a:maxratio	d:maxratio	d:maxratio
# 15	pack_by_bins	a:maxratio	d:maxratio	d:maxdiff
# 15	pack_by_bins	a:lnorm	d:maxratio	none
# 15	pack_by_bins	a:lnorm	d:maxratio	d:sum
# 15	pack_by_bins	a:lnorm	d:maxratio	d:lnorm
# 15	pack_by_bins	pp	d:maxratio	d:maxratio
# 15	pack_by_bins	pp:w=2	d:maxratio	d:maxratio
# 15	pack_by_bins	a:maxratio	d:max	d:maxratio
# 15	pack_by_bins	a:maxratio	d:max	d:maxdiff
# 15	pack_by_bins	a:maxratio	d:max	a:lnorm
# 15	pack_by_bins	a:lnorm	d:max	none
#
# unmapped	pack	select	itemsort	binsort
# 163	pack_by_bins	a:maxratio	d:lnorm	d:maxratio
# 166	pack_by_bins	a:maxratio	d:sum	d:maxratio
# 173	pack_by_bins	a:maxratio	d:maxdiff	d:maxratio
# 175	pack_by_bins	pp	d:maxratio	d:maxratio
# 175	pack_by_bins	pp:w=2	d:maxratio	d:maxratio
# 175	pack_by_bins	a:maxratio	d:max	d:maxratio
# 178	pack_by_bins	a:maxratio	d:maxratio	d:maxratio
# 197	pack_by_bins	a:maxdiff	d:maxratio	d:maxratio
# 198	pack_by_bins	a:maxdiff	a:lnorm	d:maxratio
# 198	pack_by_bins	a:maxdiff	a:max	d:maxratio
# 200	pack_by_bins	a:maxdiff	a:sum	d:maxratio
# 207	pack_by_bins	a:maxdiff	a:max	d:maxdiff
# 208	pack_by_bins	a:maxdiff	a:sum	d:maxdiff
# 210	pack_by_bins	a:maxdiff	a:lnorm	d:maxdiff
# 210	pack_by_bins	a:maxratio	none	d:maxratio
# 212	pack_by_bins	a:maxdiff	d:maxratio	d:maxdiff
# 217	pack_by_bins	pp	d:maxdiff	d:maxratio
# 217	pack_by_bins	pp:w=2	d:maxdiff	d:maxratio
# 219	pack_by_bins	a:maxratio	d:lnorm	d:maxdiff
# 219	pack_by_bins	a:maxdiff	none	d:maxratio
# 220	pack_by_bins	a:maxdiff	a:maxdiff	d:maxdiff
# 220	pack_by_bins	a:maxratio	d:sum	a:sum
# 221	pack_by_bins	a:maxratio	d:max	d:maxdiff
# 221	pack_by_bins	a:maxdiff	a:maxdiff	d:maxratio
# 221	pack_by_bins	a:maxdiff	d:maxdiff	d:maxratio
# 221	pack_by_bins	a:maxratio	d:sum	d:maxdiff
# 224	pack_by_bins	a:maxratio	d:maxdiff	d:maxdiff
# 226	pack_by_bins	a:maxdiff	none	d:maxdiff
# 228	pack_by_bins	a:maxratio	d:lnorm	a:sum
# 228	pack_by_bins	a:maxratio	d:maxratio	d:maxdiff
# 228	pack_by_bins	a:maxratio	d:maxdiff	a:sum
# 229	pack_by_bins	a:maxratio	d:max	a:sum
# 229	pack_by_items	pp	d:maxratio	d:maxratio
# 229	pack_by_items	pp:w=2	d:maxratio	d:maxratio
# 230	pack_by_bins	a:maxratio	d:maxratio	a:sum
# 231	pack_by_bins	a:maxdiff	d:maxdiff	d:maxdiff
# 241	pack_by_bins	a:maxdiff	a:maxratio	d:maxratio
# 243	pack_by_bins	a:maxratio	d:lnorm	a:lnorm
# 243	pack_by_bins	a:maxdiff	a:sum	a:sum
# 243	pack_by_bins	a:maxdiff	d:max	d:maxratio
#
# num_dimensions: 4
#
# solved	pack	select	itemsort	binsort
# 14	pack_by_bins	a:maxdiff	none	d:maxratio
# 14	pack_by_bins	a:maxdiff	d:sum	d:maxratio
# 14	pack_by_bins	a:maxratio	d:sum	d:maxratio
# 14	pack_by_bins	a:maxdiff	a:max	d:maxratio
# 14	pack_by_bins	a:maxdiff	d:maxdiff	d:maxratio
# 14	pack_by_bins	a:maxdiff	d:maxratio	d:maxratio
# 14	pack_by_bins	a:maxdiff	d:lnorm	d:maxratio
# 14	pack_by_bins	a:maxratio	d:lnorm	d:maxratio
# 13	pack_by_items	pp:w=2	none	d:max
# 13	pack_by_items	cp:w=2	none	d:maxdiff
# 13	pack_by_items	cp:w=2	none	d:lnorm
# 13	pack_by_items	pp	d:sum	a:maxratio
# 13	pack_by_items	pp	none	none
# 13	pack_by_items	pp	none	a:sum
# 13	pack_by_items	pp	none	d:sum
# 13	pack_by_items	pp	none	a:max
# 13	pack_by_items	pp	none	a:maxdiff
# 13	pack_by_items	pp	none	d:maxratio
# 13	pack_by_items	pp	none	a:maxratio
# 13	pack_by_items	pp	none	d:max
# 13	pack_by_items	pp	none	d:maxdiff
# 13	pack_by_items	pp	none	a:lnorm
# 13	pack_by_items	pp	none	d:lnorm
# 13	pack_by_items	pp:w=2	none	a:sum
# 13	pack_by_items	pp:w=2	none	none
# 13	pack_by_items	pp:w=2	none	d:sum
# 13	pack_by_items	pp:w=2	none	a:max
# 13	pack_by_items	pp:w=2	none	d:maxdiff
# 13	pack_by_items	pp:w=2	none	a:lnorm
# 13	pack_by_items	pp:w=2	none	a:maxdiff
# 13	pack_by_items	pp:w=2	none	d:lnorm
# 13	pack_by_items	pp:w=2	none	d:maxratio
# 13	pack_by_items	cp:w=2	none	none
# 13	pack_by_items	cp:w=2	none	d:sum
# 13	pack_by_items	cp:w=2	none	a:max
# 13	pack_by_items	cp:w=2	none	a:sum
# 13	pack_by_items	cp:w=2	none	d:max
# 13	pack_by_items	cp:w=2	none	a:lnorm
# 13	pack_by_items	cp:w=2	none	d:maxratio
# 13	pack_by_items	pp	a:sum	none
#
# unmapped	pack	select	itemsort	binsort
# 1215	pack_by_bins	a:maxratio	d:sum	d:maxratio
# 1228	pack_by_bins	a:maxratio	d:lnorm	d:maxratio
# 1264	pack_by_bins	a:maxratio	d:maxratio	d:maxratio
# 1276	pack_by_bins	a:maxratio	d:max	d:maxratio
# 1279	pack_by_bins	a:maxratio	d:sum	d:maxdiff
# 1280	pack_by_bins	a:maxratio	d:maxdiff	d:maxratio
# 1281	pack_by_bins	a:maxratio	d:lnorm	d:maxdiff
# 1299	pack_by_bins	a:maxratio	d:lnorm	a:sum
# 1300	pack_by_bins	a:maxratio	d:sum	a:sum
# 1339	pack_by_bins	a:maxratio	d:lnorm	a:lnorm
# 1342	pack_by_bins	a:maxratio	d:max	a:sum
# 1345	pack_by_bins	a:maxratio	d:sum	a:lnorm
# 1350	pack_by_bins	a:maxratio	d:max	d:maxdiff
# 1355	pack_by_bins	a:maxratio	d:maxratio	a:sum
# 1357	pack_by_bins	a:maxratio	d:maxdiff	a:sum
# 1358	pack_by_bins	a:maxratio	d:maxratio	d:maxdiff
# 1362	pack_by_bins	a:maxratio	d:maxdiff	d:maxdiff
# 1382	pack_by_bins	a:maxratio	none	d:maxratio
# 1389	pack_by_bins	a:maxdiff	a:max	d:maxratio
# 1396	pack_by_bins	a:maxratio	d:maxdiff	a:lnorm
# 1401	pack_by_bins	a:maxratio	d:max	a:lnorm
# 1402	pack_by_bins	a:maxratio	d:maxratio	a:lnorm
# 1406	pack_by_bins	a:maxdiff	d:maxratio	d:maxratio
# 1407	pack_by_bins	a:maxdiff	a:lnorm	d:maxratio
# 1416	pack_by_bins	a:maxdiff	a:sum	d:maxratio
# 1432	pack_by_bins	a:maxratio	d:sum	a:max
# 1437	pack_by_bins	a:maxratio	d:lnorm	a:max
# 1443	pack_by_bins	a:maxratio	none	d:maxdiff
# 1446	pack_by_bins	a:maxratio	none	a:sum
# 1451	pack_by_bins	a:maxdiff	a:max	d:maxdiff
# 1461	pack_by_bins	a:maxratio	d:sum	none
# 1469	pack_by_bins	a:maxratio	d:lnorm	none
# 1477	pack_by_bins	a:maxratio	none	a:lnorm
# 1477	pack_by_bins	a:maxdiff	a:sum	d:maxdiff
# 1478	pack_by_bins	a:maxdiff	a:lnorm	d:maxdiff
# 1482	pack_by_bins	a:maxdiff	d:maxratio	d:maxdiff
# 1500	pack_by_bins	a:maxdiff	a:max	a:sum
# 1501	pack_by_bins	a:maxdiff	a:sum	a:sum
# 1502	pack_by_bins	a:maxratio	d:max	a:max
# 1505	pack_by_bins	a:maxdiff	a:maxdiff	d:maxratio

# %%
# problem-wise aggregation...
results = solutions.group(['problem-argshash', 'num_dimensions', 'num_bins', 'num_items', 'slack', 'cov', 'split'], {}, { 'solver_count' : 0, 'solvers' : [] },
                          'function(curr, result) { if (curr.failcount == 0) { result.solver_count++; result.solvers.push(curr.pack ' +
                          '+ "_" + curr.select + "_" + curr.itemsort + "_" + curr.binsort); } }')

for result in sorted(results, key=lambda x: x['solver_count']):
    print "%(problem-argshash)s\t%(num_dimensions)d\t%(num_bins)d\t%(num_items)d\t%(slack)f\t%(cov)f\t%(split)d\t%(solver_count)d" % result
    if result['solver_count'] < 100:
        print result['solvers']
# Out:
# b68f8111cc3c7ff243c5c44c947bb25aae6f680f	3	512	2000	0.200000	1.000000	2	0
# []
# 547b2d94775ab9f6335694627a1b37e0350a738d	2	512	2000	0.200000	0.660000	8	0
# []
# f72f96becf69f1f6083e6856946daa1ea495daef	4	512	4000	0.400000	1.000000	4	0
# []
# 4b2ddab48d5d34c3f84a2496ae247a5b8db06674	4	512	5000	0.200000	1.000000	8	0
# []
# f3826b2f60f2f41484da4e3347bbf87ac4d2a5e5	4	512	3000	0.200000	0.660000	1	8
# [u'pack_by_bins_a:maxdiff_none_d:maxratio', u'pack_by_bins_a:maxdiff_d:sum_d:maxratio', u'pack_by_bins_a:maxratio_d:sum_d:maxratio', u'pack_by_bins_a:maxdiff_a:max_d:maxratio', u'pack_by_bins_a:maxdiff_d:maxdiff_d:maxratio', u'pack_by_bins_a:maxdiff_d:maxratio_d:maxratio', u'pack_by_bins_a:maxdiff_d:lnorm_d:maxratio', u'pack_by_bins_a:maxratio_d:lnorm_d:maxratio']
# d3e150e5f6f974720773d925f9f0e0df4f246552	3	512	4000	0.200000	0.660000	4	108
# d177c04a1f1111bfc09170042830415b633a6219	2	512	4000	0.200000	1.000000	1	490
# a44e7947cd74ec8019abdec9f432df8ac471a723	3	512	5000	0.400000	0.660000	8	811
# 8f9bcf3dae9b48c0a24dd20712abbf0183c403f6	3	512	3000	0.400000	1.000000	1	1020
# d7b976b041db66cdfb463b1f878b57f11d4d1a99	4	512	2000	0.400000	0.660000	2	1109
# b8d31a763c67c2c55c9515d241ad89aaf446113b	4	512	3000	0.600000	1.000000	2	1372
# 329d6da25cc4d96f2a42cf5c4e9a906547d53662	4	512	2000	0.200000	0.330000	4	1667
# a97ba9f2efa64c3a60e810cbf8014c9f65627039	3	512	4000	0.600000	1.000000	8	1698
# c88e8dd15b02ff4e275f5bfe80d95703be22e2a9	3	512	5000	0.200000	0.330000	1	2566
# bbcbf5346a7094ca82c13a29974bc4fe30435f81	2	512	3000	0.200000	0.330000	2	2744
# 1781e675f4554bde88ed9b7e033046ceab012389	2	512	5000	0.400000	1.000000	2	2797
# c4975824b59245de60f04e73078bf58af5560af7	4	512	5000	0.600000	0.660000	4	2837
# 72633825662bd2ed4e1e7f8aa1e9f8541f316f4b	4	512	3000	0.400000	0.330000	8	2887
# 56230ff17f63bfc1aca0d22ef53fbcf2d215ffb2	3	512	3000	0.200000	0.000000	8	2937
# 27503408852e4882da8daaf1f490ae900ad7bc3f	2	512	3000	0.400000	0.660000	4	2974
# 882c5450f2f0613543c21d157e1719db78da9589	4	512	4000	0.200000	0.000000	2	3102
# 6c4f4e1caf40555840c43a32cd23e84b6dd5fc18	3	512	4000	0.400000	0.330000	2	3157
# b1ea2a1387f27a8018f2a9a2fe0057d051061964	3	512	2000	0.600000	0.660000	1	3290
# 0e063e0e58de0e78707449e393f1555dadca5fba	1	512	2000	0.200000	0.000000	1	3465
# 9536574abbd78cb7ea3222fc4cd64c727523fa48	2	512	2000	0.600000	1.000000	4	3554
# cd7222f1d6b77da9695ed063fc151ffd00782d0e	2	512	5000	0.200000	0.000000	4	3575
# 3eb9ff2772f49efac646d7a8bba000eda7c86622	4	512	2000	0.800000	1.000000	1	3622
# 5366fe7df03b46cf96ea50847aeda9438fe73d0c	3	512	3000	0.600000	0.330000	4	3630
# 23cb51c88cf4e5a514ff839226e02f5080a576e7	2	512	4000	0.800000	0.330000	4	3630
# 06cdf4159a54d51451f56892feeca9470fea377d	2	512	4000	0.400000	0.000000	8	3630
# a0c19986ae1e0ac6d9932638d343ab7906e3160e	2	512	3000	0.600000	0.000000	1	3630
# e6468e786039a46440b396ba33c519886344b707	2	512	2000	0.400000	0.330000	1	3630
# f3f492362559985279c4bb8e412f5daad642b560	3	512	2000	0.800000	0.330000	8	3630
# 68e70e8a9768cfe5d6069d3d0ed8b844b8246189	1	512	4000	0.800000	1.000000	2	3630
# 59c6d5be4839a18eef2ae184ebe1db9d3bb6f728	1	512	5000	0.600000	1.000000	1	3630
# de9417ab35c1d43a4e5161ace229348c3c387f7c	3	512	2000	0.400000	0.000000	4	3630
# fd2159a3c07700cad73afadf90ea472baa5586a0	1	512	3000	0.200000	1.000000	4	3630
# b0ae80c17126f790df8780078a62ea4820314176	2	512	2000	0.800000	0.000000	2	3630
# 5c4d17405f4580456bc5471bb8da2347d0a1868c	2	512	3000	0.800000	1.000000	8	3630
# 423f22895a3c68575cf2f2e86d1d0dae6179692a	1	512	3000	0.600000	0.660000	8	3630
# 84f3c9fab098f52d758104716da00faa700b38eb	1	512	4000	0.400000	0.660000	1	3630
# 2e52ee3207527cd666563916a377d56c35094d22	1	512	5000	0.200000	0.660000	2	3630
# fc6b72a34520753877ab8968839e82be3ac98af0	1	512	2000	0.400000	1.000000	8	3630
# 430fc9a1d4462cef04507aff1d4bbec3b6064f5e	1	512	3000	0.800000	0.330000	1	3630
# 99f7b8828262aaf600b725b71d4595961f59698e	1	512	4000	0.200000	0.330000	8	3630
# 649d797457f60e7bffd51fe75b57446dd384e768	1	512	5000	0.400000	0.330000	4	3630
# 636d035988cb58334fa49dd0274c7556646d22b8	1	512	2000	0.800000	0.660000	4	3630
# 1d53c737550f369753c3d4bddec36c9f91915ed9	1	512	3000	0.400000	0.000000	2	3630
# 4c0f37b67e9e56639d4af540036d6844853c8485	1	512	4000	0.600000	0.000000	4	3630
# 1c33220d0a8752ce55a4c83975fbfd13cd2ae2d9	1	512	5000	0.800000	0.000000	8	3630
# 33a9d06131d6bfd933e31b421ebea6016583b90d	1	512	2000	0.600000	0.330000	2	3630
# ae327898d3faf08f8f49c3ed9fd6ddaf3dc94a61	2	512	5000	0.600000	0.330000	8	3630
# 4202dbec6c756608631c98810a099085d593fbff	2	512	4000	0.600000	0.660000	2	3630
# 8ccbfe506ead8ea332109e14eeeddd90542fdced	2	512	5000	0.800000	0.660000	1	3630
# 57a614af0556e42908ca175c2fe5df297162c9a3	3	512	4000	0.800000	0.000000	1	3630
# 2e1ad7cfd43760de76b8cba45ed247346307534e	3	512	5000	0.600000	0.000000	2	3630
# 4a8f9ecd80d0dd1e788a5ae8e64359cc2589e336	3	512	3000	0.800000	0.660000	2	3630
# c3fe27640ba1657289d0aebcdc526860b774fddb	3	512	5000	0.800000	1.000000	4	3630
# 533fdcfb94f15c54f64c50c9eebc575607a6d4c1	4	512	2000	0.600000	0.000000	8	3630
# c73c6d43ff6862c121ea370f23eac9c7e2a6ae6c	4	512	3000	0.800000	0.000000	4	3630
# b46419f30028138e86e90bc5a97bac8ed1db6452	4	512	5000	0.400000	0.000000	1	3630
# ca7fe539bb7cee3fd758fbbf9c912eac6b7b8ef0	4	512	4000	0.600000	0.330000	1	3630
# 141840ac85a9c1493807b6944f71807165c895d3	4	512	5000	0.800000	0.330000	2	3630
# 8982f2913191392706f7d38efd849d6175362b88	4	512	4000	0.800000	0.660000	8	3630

# %%
for result in sorted(results, key=lambda x: x['solver_count']):
    if 'pack_by_bins_a:maxratio_d:sum_d:maxratio' not in result['solvers']:
        print "%(problem-argshash)s\t%(num_dimensions)d\t%(num_bins)d\t%(num_items)d\t%(slack)f\t%(cov)f\t%(split)d\t%(solver_count)d" % result
# Out:
# b68f8111cc3c7ff243c5c44c947bb25aae6f680f	3	512	2000	0.200000	1.000000	2	0
# 547b2d94775ab9f6335694627a1b37e0350a738d	2	512	2000	0.200000	0.660000	8	0
# f72f96becf69f1f6083e6856946daa1ea495daef	4	512	4000	0.400000	1.000000	4	0
# 4b2ddab48d5d34c3f84a2496ae247a5b8db06674	4	512	5000	0.200000	1.000000	8	0

# %%
for result in sorted(results, key=lambda x: x['solver_count']):
    if result['solver_count'] < 200:
        print result['problem-argshash'], result['solvers']
# Out:
# b68f8111cc3c7ff243c5c44c947bb25aae6f680f []
# 547b2d94775ab9f6335694627a1b37e0350a738d []
# f72f96becf69f1f6083e6856946daa1ea495daef []
# 4b2ddab48d5d34c3f84a2496ae247a5b8db06674 []
# f3826b2f60f2f41484da4e3347bbf87ac4d2a5e5 [u'pack_by_bins_a:maxdiff_none_d:maxratio', u'pack_by_bins_a:maxdiff_d:sum_d:maxratio', u'pack_by_bins_a:maxratio_d:sum_d:maxratio', u'pack_by_bins_a:maxdiff_a:max_d:maxratio', u'pack_by_bins_a:maxdiff_d:maxdiff_d:maxratio', u'pack_by_bins_a:maxdiff_d:maxratio_d:maxratio', u'pack_by_bins_a:maxdiff_d:lnorm_d:maxratio', u'pack_by_bins_a:maxratio_d:lnorm_d:maxratio']
# d3e150e5f6f974720773d925f9f0e0df4f246552 [u'pack_by_items_pp_d:maxdiff_d:maxratio', u'pack_by_items_pp:w=2_d:maxdiff_d:maxratio', u'pack_by_items_pp_d:maxratio_d:maxratio', u'pack_by_items_pp:w=2_d:maxratio_d:maxratio', u'pack_by_bins_a:maxdiff_none_a:sum', u'pack_by_bins_a:maxdiff_none_none', u'pack_by_bins_a:maxdiff_none_d:maxratio', u'pack_by_bins_a:maxdiff_none_d:maxdiff', u'pack_by_bins_a:maxdiff_none_a:lnorm', u'pack_by_bins_a:maxratio_none_a:sum', u'pack_by_bins_a:maxratio_none_d:maxratio', u'pack_by_bins_a:maxratio_none_d:maxdiff', u'pack_by_bins_a:lnorm_none_none', u'pack_by_bins_a:lnorm_none_d:sum', u'pack_by_bins_a:lnorm_none_d:lnorm', u'pack_by_bins_a:maxdiff_a:sum_a:sum', u'pack_by_bins_a:maxdiff_a:sum_d:maxdiff', u'pack_by_bins_a:maxdiff_a:sum_d:maxratio', u'pack_by_bins_a:maxdiff_a:sum_a:lnorm', u'pack_by_bins_a:lnorm_a:sum_none', u'pack_by_bins_a:lnorm_a:sum_a:max', u'pack_by_bins_a:lnorm_a:sum_d:sum', u'pack_by_bins_a:lnorm_a:sum_d:lnorm', u'pack_by_bins_a:maxdiff_d:sum_a:sum', u'pack_by_bins_a:maxdiff_d:sum_none', u'pack_by_bins_a:maxdiff_d:sum_d:maxdiff', u'pack_by_bins_a:maxdiff_d:sum_d:maxratio', u'pack_by_bins_a:maxdiff_d:sum_a:lnorm', u'pack_by_bins_a:maxratio_d:sum_a:sum', u'pack_by_bins_a:maxratio_d:sum_d:maxdiff', u'pack_by_bins_a:maxratio_d:sum_d:maxratio', u'pack_by_bins_a:maxratio_d:sum_a:lnorm', u'pack_by_bins_a:lnorm_d:sum_none', u'pack_by_bins_a:lnorm_d:sum_d:sum', u'pack_by_bins_a:lnorm_d:sum_d:lnorm', u'pack_by_bins_a:maxdiff_a:max_a:sum', u'pack_by_bins_a:maxdiff_a:max_d:maxdiff', u'pack_by_bins_a:maxdiff_a:max_d:maxratio', u'pack_by_bins_a:lnorm_a:max_none', u'pack_by_bins_a:lnorm_a:max_d:sum', u'pack_by_bins_a:lnorm_a:max_d:lnorm', u'pack_by_bins_a:maxdiff_d:max_a:sum', u'pack_by_bins_a:maxdiff_d:max_none', u'pack_by_bins_a:maxdiff_d:max_d:maxdiff', u'pack_by_bins_a:maxdiff_d:max_d:maxratio', u'pack_by_bins_a:maxratio_d:max_a:sum', u'pack_by_bins_a:maxratio_d:max_d:maxdiff', u'pack_by_bins_a:maxratio_d:max_d:maxratio', u'pack_by_bins_a:maxratio_d:max_a:lnorm', u'pack_by_bins_a:lnorm_d:max_none', u'pack_by_bins_a:lnorm_d:max_d:sum', u'pack_by_bins_a:lnorm_d:max_d:lnorm', u'pack_by_bins_a:maxdiff_a:maxdiff_a:sum', u'pack_by_bins_a:maxdiff_a:maxdiff_d:maxdiff', u'pack_by_bins_a:maxdiff_a:maxdiff_d:maxratio', u'pack_by_bins_a:maxdiff_a:maxdiff_a:lnorm', u'pack_by_bins_a:lnorm_a:maxdiff_none', u'pack_by_bins_a:lnorm_a:maxdiff_d:sum', u'pack_by_bins_a:lnorm_a:maxdiff_d:lnorm', u'pack_by_bins_a:maxdiff_d:maxdiff_a:sum', u'pack_by_bins_a:maxdiff_d:maxdiff_d:maxdiff', u'pack_by_bins_a:maxdiff_d:maxdiff_d:maxratio', u'pack_by_bins_a:maxdiff_d:maxdiff_a:lnorm', u'pack_by_bins_a:maxratio_d:maxdiff_a:sum', u'pack_by_bins_a:maxratio_d:maxdiff_d:maxdiff', u'pack_by_bins_a:maxratio_d:maxdiff_d:maxratio', u'pack_by_bins_a:maxratio_d:maxdiff_a:lnorm', u'pack_by_bins_a:lnorm_d:maxdiff_none', u'pack_by_bins_a:lnorm_d:maxdiff_d:sum', u'pack_by_bins_a:lnorm_d:maxdiff_d:lnorm', u'pack_by_bins_pp_d:maxdiff_d:maxratio', u'pack_by_bins_pp:w=2_d:maxdiff_d:maxratio', u'pack_by_bins_a:maxdiff_a:maxratio_a:sum', u'pack_by_bins_a:maxdiff_a:maxratio_d:maxdiff', u'pack_by_bins_a:maxdiff_a:maxratio_d:maxratio', u'pack_by_bins_a:lnorm_a:maxratio_none', u'pack_by_bins_a:lnorm_a:maxratio_d:sum', u'pack_by_bins_a:lnorm_a:maxratio_d:lnorm', u'pack_by_bins_a:maxdiff_d:maxratio_a:sum', u'pack_by_bins_a:maxdiff_d:maxratio_d:maxdiff', u'pack_by_bins_a:maxdiff_d:maxratio_d:maxratio', u'pack_by_bins_a:maxratio_d:maxratio_a:sum', u'pack_by_bins_a:maxratio_d:maxratio_d:maxdiff', u'pack_by_bins_a:maxratio_d:maxratio_d:maxratio', u'pack_by_bins_a:lnorm_d:maxratio_none', u'pack_by_bins_a:lnorm_d:maxratio_d:sum', u'pack_by_bins_a:lnorm_d:maxratio_d:lnorm', u'pack_by_bins_pp_d:maxratio_d:maxratio', u'pack_by_bins_pp:w=2_d:maxratio_d:maxratio', u'pack_by_bins_a:maxdiff_a:lnorm_a:sum', u'pack_by_bins_a:maxdiff_a:lnorm_d:maxdiff', u'pack_by_bins_a:maxdiff_a:lnorm_d:maxratio', u'pack_by_bins_a:maxdiff_a:lnorm_a:lnorm', u'pack_by_bins_a:lnorm_a:l ...

# %%
import matplotlib.pyplot as plt
from pandas import DataFrame

# %%
results = solutions.group(['num_dimensions'], {}, 
                          { 'chosen_fails' : 0, 'avg_fails' : 0, 'bf_fails' : 0, 'bfl2_fails' : 0 },
                          '''
                          function(curr, result) { 
                              if (curr.pack == 'pack_by_bins' && curr.select == 'a:maxratio' && 
                                  curr.itemsort == 'd:sum' && curr.binsort == 'd:maxratio') { 
                                  result.chosen_fails += curr.failcount;
                              }
                              if (curr.pack == 'pack_by_bins' && curr.select == 'a:sum' && 
                                  curr.itemsort == 'd:sum' && curr.binsort == 'a:sum') { 
                                  result.bf_fails += curr.failcount;
                              }
                              if (curr.pack == 'pack_by_bins' && curr.select == 'a:lnorm' && 
                                  curr.itemsort == 'd:lnorm' && curr.binsort == 'a:lnorm') { 
                                  result.bfl2_fails += curr.failcount;
                              }
                              result.avg_fails += 1.0 * curr.failcount / 3630.0;
                          }''')

for result in sorted(results, key=lambda x: x['num_dimensions']):
    print "%(num_dimensions)d\t%(chosen_fails)d\t%(bf_fails)d\t%(bfl2_fails)d\t%(avg_fails)f" % result
# Out:
# 1	0	0	0	2.181818
# 2	14	1345	52	1253.228375
# 3	166	3707	560	3182.079890
# 4	1215	7097	3133	5989.829201

# %%
results.sort(key=lambda x: x['num_dimensions'])
results_df = DataFrame(results)
print results_df
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(results_df['num_dimensions'], results_df['chosen_fails'], label='chosen fails')
ax.plot(results_df['num_dimensions'], results_df['bf_fails'], label='bf fails')
ax.plot(results_df['num_dimensions'], results_df['bfl2_fails'], label='bf l2 fails')
plt.xlim(min(results_df['num_dimensions']), max(results_df['num_dimensions']))
plt.legend()
plt.show()
# Out:
#      avg_fails  bf_fails  bfl2_fails  chosen_fails  num_dimensions
# 0     2.181818         0           0             0               1
# 1  1253.228375      1345          52            14               2
# 2  3182.079890      3707         560           166               3
# 3  5989.829201      7097        3133          1215               4

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(samples_df['time'], samples_df['cpu_requested'], label='cpu requested')
ax.plot(samples_df['time'], samples_df['mem_requested'], label='mem requested')
plt.xlim(min(samples_df['time']), max(samples_df['time']))
plt.legend()
plt.show()

# %%
results = solutions.group(['num_items'], {}, 
                          { 'chosen_fails' : 0, 'avg_fails' : 0, 'bf_fails' : 0, 'bfl2_fails' : 0 },
                          '''
                          function(curr, result) { 
                              if (curr.pack == 'pack_by_bins' && curr.select == 'a:maxratio' && 
                                  curr.itemsort == 'd:sum' && curr.binsort == 'd:maxratio') { 
                                  result.chosen_fails += curr.failcount;
                              }
                              if (curr.pack == 'pack_by_bins' && curr.select == 'a:sum' && 
                                  curr.itemsort == 'd:sum' && curr.binsort == 'a:sum') { 
                                  result.bf_fails += curr.failcount;
                              }
                              if (curr.pack == 'pack_by_bins' && curr.select == 'a:lnorm' && 
                                  curr.itemsort == 'd:lnorm' && curr.binsort == 'a:lnorm') { 
                                  result.bfl2_fails += curr.failcount;
                              }
                              result.avg_fails += 1.0 * curr.failcount / 3630.0;
                          }''')

for result in sorted(results, key=lambda x: x['num_items']):
    print "%(num_items)d\t%(chosen_fails)d\t%(bf_fails)d\t%(bfl2_fails)d\t%(avg_fails)f" % result
# Out:
# 2000	180	1284	569	1419.598898
# 3000	0	2603	281	2094.344904
# 4000	113	4492	566	3175.491736
# 5000	1102	3770	2329	3737.883747

# %%
results = solutions.group(['slack'], {}, 
                          { 'chosen_fails' : 0, 'avg_fails' : 0, 'bf_fails' : 0, 'bfl2_fails' : 0 },
                          '''
                          function(curr, result) { 
                              if (curr.pack == 'pack_by_bins' && curr.select == 'a:maxratio' && 
                                  curr.itemsort == 'd:sum' && curr.binsort == 'd:maxratio') { 
                                  result.chosen_fails += curr.failcount;
                              }
                              if (curr.pack == 'pack_by_bins' && curr.select == 'a:sum' && 
                                  curr.itemsort == 'd:sum' && curr.binsort == 'a:sum') { 
                                  result.bf_fails += curr.failcount;
                              }
                              if (curr.pack == 'pack_by_bins' && curr.select == 'a:lnorm' && 
                                  curr.itemsort == 'd:lnorm' && curr.binsort == 'a:lnorm') { 
                                  result.bfl2_fails += curr.failcount;
                              }
                              result.avg_fails += 1.0 * curr.failcount / 3630.0;
                          }''')

for result in sorted(results, key=lambda x: x['slack']):
    print "%(slack)f\t%(chosen_fails)d\t%(bf_fails)d\t%(bfl2_fails)d\t%(avg_fails)f" % result
# Out:
# 0.200000	1282	8246	3222	6887.949587
# 0.400000	113	3420	523	2856.438292
# 0.600000	0	483	0	682.893939
# 0.800000	0	0	0	0.037466

# %%
results = solutions.group(['cov'], {}, 
                          { 'chosen_fails' : 0, 'avg_fails' : 0, 'bf_fails' : 0, 'bfl2_fails' : 0 },
                          '''
                          function(curr, result) { 
                              if (curr.pack == 'pack_by_bins' && curr.select == 'a:maxratio' && 
                                  curr.itemsort == 'd:sum' && curr.binsort == 'd:maxratio') { 
                                  result.chosen_fails += curr.failcount;
                              }
                              if (curr.pack == 'pack_by_bins' && curr.select == 'a:sum' && 
                                  curr.itemsort == 'd:sum' && curr.binsort == 'a:sum') { 
                                  result.bf_fails += curr.failcount;
                              }
                              if (curr.pack == 'pack_by_bins' && curr.select == 'a:lnorm' && 
                                  curr.itemsort == 'd:lnorm' && curr.binsort == 'a:lnorm') { 
                                  result.bfl2_fails += curr.failcount;
                              }
                              result.avg_fails += 1.0 * curr.failcount / 3630.0;
                          }''')

for result in sorted(results, key=lambda x: x['cov']):
    print "%(cov)f\t%(chosen_fails)d\t%(bf_fails)d\t%(bfl2_fails)d\t%(avg_fails)f" % result
# Out:
# 0.000000	0	0	0	106.996970
# 0.330000	0	0	0	707.559229
# 0.660000	14	3805	366	3063.898347
# 1.000000	1381	8344	3379	6548.864738

# %%
results = solutions.group(['split'], {}, 
                          { 'chosen_fails' : 0, 'avg_fails' : 0, 'bf_fails' : 0, 'bfl2_fails' : 0 },
                          '''
                          function(curr, result) { 
                              if (curr.pack == 'pack_by_bins' && curr.select == 'a:maxratio' && 
                                  curr.itemsort == 'd:sum' && curr.binsort == 'd:maxratio') { 
                                  result.chosen_fails += curr.failcount;
                              }
                              if (curr.pack == 'pack_by_bins' && curr.select == 'a:sum' && 
                                  curr.itemsort == 'd:sum' && curr.binsort == 'a:sum') { 
                                  result.bf_fails += curr.failcount;
                              }
                              if (curr.pack == 'pack_by_bins' && curr.select == 'a:lnorm' && 
                                  curr.itemsort == 'd:lnorm' && curr.binsort == 'a:lnorm') { 
                                  result.bfl2_fails += curr.failcount;
                              }
                              result.avg_fails += 1.0 * curr.failcount / 3630.0;
                          }''')

for result in sorted(results, key=lambda x: x['split']):
    print "%(split)d\t%(chosen_fails)d\t%(bf_fails)d\t%(bfl2_fails)d\t%(avg_fails)f" % result
# Out:
# 1	0	3317	286	2501.269972
# 2	166	1577	522	1773.116804
# 4	113	3295	561	2559.627824
# 8	1116	3960	2376	3593.304683

# %%
results = solutions.group(['split'], {}, 
                          { 'chosen_runtime' : 0.0, 'avg_runtime' : 0.0, 'bf_runtime' : 0.0, 'pp_runtime' : 0.0 },
                          '''
                          function(curr, result) { 
                              if (curr.pack == 'pack_by_bins' && curr.select == 'a:maxratio' && 
                                  curr.itemsort == 'd:sum' && curr.binsort == 'd:maxratio') { 
                                  result.chosen_runtime += curr.runtime / 16;
                              }
                              if (curr.pack == 'pack_by_bins' && curr.select == 'a:sum' && 
                                  curr.itemsort == 'd:sum' && curr.binsort == 'a:sum') { 
                                  result.bf_runtime += curr.runtime / 16;
                              }
                              if (curr.pack == 'pack_by_bins' && curr.select == 'pp' && 
                                  curr.itemsort == 'd:sum' && curr.binsort == 'a:sum') { 
                                  result.pp_runtime += curr.runtime / 16;
                              }
                              result.avg_runtime += curr.runtime / 3630 / 16;
                          }''')
for result in sorted(results, key=lambda x: x['split']):
    print "%(split)d\t%(chosen_runtime)f\t%(bf_runtime)f\t%(pp_runtime)f\t%(avg_runtime)f" % result
# Out:
# 1	232.526927	149.167829	184.709713	104.145572
# 2	115.578299	75.739299	91.533899	52.331166
# 4	58.091077	37.103702	46.030299	25.884167
# 8	28.910615	18.136857	22.509322	12.766497
